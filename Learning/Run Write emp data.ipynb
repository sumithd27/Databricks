# %%
#run the child notebook with parameter - sales or production or office 
_count = dbutils.notebook.run(
    path = "Write Emp Data",
    timeout_seconds=600,
    arguments = {"dept": "office"},
    )
print(f"child Notebook count is {_count}")
