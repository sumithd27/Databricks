-- %%
--create New schema
create schema if not exists learning.etl
comment 'Schema for DLT Intoduction'

-- %%
Create Schema if not Exists learning.bronze

-- %%
--Clone some sample tables
 Create table if not exists learning.bronze.orders_raw DEEP CLONE samples.tpch.orders;
 Create table if not exists learning.bronze.customer_raw DEEP CLONE samples.tpch.customer;

-- %%
select * from learning.bronze.orders_raw

-- %%
select * from learning.bronze.customer_raw
